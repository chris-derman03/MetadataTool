# %%
import numpy as np
import pandas as pd

# %%
source_datafile = "../out/png_metadata.csv"

imageMetadata = pd.read_csv(source_datafile)
imageMetadata.T.head(50)
# Out:
#                                                                              0  \
# SourceFile                                      example_image_bin/IMG_0353.jpg
# AccelerationVector                    0.1188487486 -0.1806282252 -0.9600576167
# AEAverage                                                                   93
# AEStable                                                                   Yes
# AETarget                                                                    92
# AFConfidence                                                                12
# AFMeasuredDepth                                                             17
# AFStable                                                                   Yes
# Aperture                                                                   1.5
# ApertureValue                                                              1.5
# BitsPerSample                                                                8
# ...

# %%
np.array(imageMetadata.columns)
# Out:
# array(['SourceFile', 'AccelerationVector', 'AEAverage', 'AEStable',
#        'AETarget', 'AFConfidence', 'AFMeasuredDepth', 'AFStable',
#        'Aperture', 'ApertureValue', 'BitsPerSample', 'BlueMatrixColumn',
#        'BlueTRC', 'BrightnessValue', 'ChromaticAdaptation',
#        'CircleOfConfusion', 'CMMFlags', 'ColorComponents', 'ColorSpace',
#        'ColorSpaceData', 'ComponentsConfiguration', 'CompositeImage',
#        'CompositeImageCount', 'CompositeImageExposureTimes',
#        'Compression', 'ConnectionSpaceIlluminant', 'ContentIdentifier',
#        'CreateDate', 'DateTimeOriginal', 'DependentImage1EntryNumber',
#        'DependentImage2EntryNumber', 'DeviceAttributes',
#        'DeviceManufacturer', 'DeviceModel', 'Directory',
#        'EncodingProcess', 'ExifByteOrder', 'ExifImageHeight',
#        'ExifImageWidth', 'ExifToolVersion', 'ExifVersion',
#        'ExposureCompensation', 'ExposureMode', 'ExposureProgram',
# ...
